# %% [markdown]
# # Python arguments

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# if we want to modify a default values
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Args

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
# por convencion se llama args pero puede ser * seguido de cualquier nombre 

def add(*numbers):
    number_list = [n for n in numbers]
    print(sum(number_list))

# el argumento * colecciona todos los elementos que pasemos como una tupla que la función add operará
add(1,2,3,4,5)
# Out:
# 15

# %% [markdown]
# son arguments posicionales porque la posicion en la que pasamos el argumento es importante
# numbers[0] = 1
# numbers[1] = 2
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
